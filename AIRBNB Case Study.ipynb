# %% [markdown]
# # Problem Statement

# %% [raw]
# Airbnb Revenue Revitalization through Data-Driven Insights
#
# Objective:
#
# As a data analyst at Airbnb, our goal is to leverage the available dataset to derive actionable insights and recommendations that will aid the company in revitalizing its revenue post the pandemic downturn. The key focus areas include host acquisition strategies, customer preferences, targeted neighborhoods, pricing optimization, property types, and customer-oriented adjustments. Additionally, there's a need to identify popular localities and properties in New York and devise strategies to enhance the visibility of less popular properties.

# %% [markdown]
# # Importing Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
bnb_df = pd.read_csv('AB_NYC_2019.csv')
bnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# #### Data Wrangling and EDA

# %%
def availability_365_categories_function(row):
    """
    Categorizes the "minimum_nights" column into 5 categories
    """
    if row <= 1:
        return 'very Low'
    elif row <= 100:
        return 'Low'
    elif row <= 200 :
        return 'Medium'
    elif (row <= 300):
        return 'High'
    else:
        return 'very High'

# %%
bnb_df['availability_365_categories'] = bnb_df.availability_365.map(availability_365_categories_function)
bnb_df['availability_365_categories']
# Out:
# 0        very High
# 1        very High
# 2        very High
# 3           Medium
# 4         very Low
#            ...
# 48890          Low
# 48891          Low
# 48892          Low
# 48893          Low
# 48894          Low
# Name: availability_365_categories, Length: 48895, dtype: object

# %%
bnb_df['availability_365_categories'].value_counts()
# Out:
# very Low     17941
# Low          11829
# very High     8108
# Medium        5792
# High          5225
# Name: availability_365_categories, dtype: int64

# %%
def minimum_night_categories_function(row):
    """
    Categorizes the "minimum_nights" column into 5 categories
    """
    if row <= 1:
        return 'very Low'
    elif row <= 3:
        return 'Low'
    elif row <= 5 :
        return 'Medium'
    elif (row <= 7):
        return 'High'
    else:
        return 'very High'

# %%
print(minimum_night_categories_function(7))
print(minimum_night_categories_function(1))
print(minimum_night_categories_function(0))
print(minimum_night_categories_function(-1))
# Out:
# High
# very Low
# very Low
# very Low

# %%
bnb_df['minimum_night_categories'] = bnb_df.minimum_nights.map(minimum_night_categories_function)
bnb_df['minimum_night_categories']
# Out:
# 0         very Low
# 1         very Low
# 2              Low
# 3         very Low
# 4        very High
#            ...
# 48890          Low
# 48891       Medium
# 48892    very High
# 48893     very Low
# 48894         High
# Name: minimum_night_categories, Length: 48895, dtype: object

# %%
bnb_df.minimum_night_categories.value_counts()
# Out:
# Low          19695
# very Low     12720
# very High     7333
# Medium        6337
# High          2810
# Name: minimum_night_categories, dtype: int64

# %%
def number_of_reviews_categories_function(row):
    """
    Categorizes the "number_of_reviews" column into 5 categories
    """
    if row <= 1:
        return 'very Low'
    elif row <= 5:
        return 'Low'
    elif row <= 10 :
        return 'Medium'
    elif (row <= 30):
        return 'High'
    else:
        return 'very High'

# %%
bnb_df['number_of_reviews_categories'] = bnb_df.minimum_nights.map(number_of_reviews_categories_function)
bnb_df['number_of_reviews_categories']
# Out:
# 0        very Low
# 1        very Low
# 2             Low
# 3        very Low
# 4          Medium
#            ...
# 48890         Low
# 48891         Low
# 48892      Medium
# 48893    very Low
# 48894      Medium
# Name: number_of_reviews_categories, Length: 48895, dtype: object

# %%
bnb_df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
bnb_df.price.plot.box()
# Out:
# <Axes: >

# %%
bnb_df[bnb_df.price == 0].shape
# Out:
# (11, 19)

# %%
def price_categories_function(row):
    """
    Categorizes the "number_of_reviews" column into 5 categories
    """
    if row <= 1:
        return 'very Low'
    elif row <= 4:
        return 'Low'
    elif row <= 15 :
        return 'Medium'
    elif (row <= 100):
        return 'High'
    else:
        return 'very High'

# %%
bnb_df['price_categories'] = bnb_df.minimum_nights.map(price_categories_function)
bnb_df['price_categories']
# Out:
# 0        very Low
# 1        very Low
# 2             Low
# 3        very Low
# 4          Medium
#            ...
# 48890         Low
# 48891         Low
# 48892      Medium
# 48893    very Low
# 48894      Medium
# Name: price_categories, Length: 48895, dtype: object

# %%
# Checking null values

bnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
bnb_df.last_review = pd.to_datetime(bnb_df.last_review)
bnb_df.last_review
# Out:
# 0       2018-10-19
# 1       2019-05-21
# 2              NaT
# 3       2019-05-07
# 4       2018-11-19
#            ...
# 48890          NaT
# 48891          NaT
# 48892          NaT
# 48893          NaT
# 48894          NaT
# Name: last_review, Length: 48895, dtype: datetime64[ns]

# %%
bnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'availability_365_categories',
#        'minimum_night_categories', 'number_of_reviews_categories',
#        'price_categories'],
#       dtype='object')

# %% [markdown]
# # Data Types

# %%
categorical_columns = bnb_df.columns[[0,1,3,4,5,8,16,17,18,19]]
categorical_columns
# Out:
# Index(['id', 'name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'availability_365_categories', 'minimum_night_categories',
#        'number_of_reviews_categories', 'price_categories'],
#       dtype='object')

# %%
bnb_df[categorical_columns].head()
# Out:
#      id                                              name    host_name  \
# 0  2539                Clean & quiet apt home by the park         John
# 1  2595                             Skylit Midtown Castle     Jennifer
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth
# 3  3831                   Cozy Entire Floor of Brownstone  LisaRoxanne
# 4  5022  Entire Apt: Spacious Studio/Loft by central park        Laura
#
#   neighbourhood_group neighbourhood        room_type  \
# 0            Brooklyn    Kensington     Private room
# 1           Manhattan       Midtown  Entire home/apt
# 2           Manhattan        Harlem     Private room
# 3            Brooklyn  Clinton Hill  Entire home/apt
# 4           Manhattan   East Harlem  Entire home/apt
#
#   availability_365_categories minimum_night_categories  \
# 0                   very High                 very Low
# 1                   very High                 very Low
# ...

# %%
numerical_columns = bnb_df.columns[[9,10,11,13,14,15]]
numerical_columns
# Out:
# Index(['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
bnb_df[numerical_columns].head()
# Out:
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
# 2    150               3                  0                NaN
# 3     89               1                270               4.64
# 4     80              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
bnb_df[numerical_columns].describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  48895.000000    48895.000000       48895.000000       38843.000000
# mean     152.720687        7.029962          23.274466           1.373221
# std      240.154170       20.510550          44.550582           1.680442
# min        0.000000        1.000000           0.000000           0.010000
# 25%       69.000000        1.000000           1.000000           0.190000
# 50%      106.000000        3.000000           5.000000           0.720000
# 75%      175.000000        5.000000          24.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# ...

# %%
coordinates = bnb_df.columns[[5,6,12]]
bnb_df[coordinates]
# Out:
#             neighbourhood  latitude last_review
# 0              Kensington  40.64749  2018-10-19
# 1                 Midtown  40.75362  2019-05-21
# 2                  Harlem  40.80902         NaT
# 3            Clinton Hill  40.68514  2019-05-07
# 4             East Harlem  40.79851  2018-11-19
# ...                   ...       ...         ...
# 48890  Bedford-Stuyvesant  40.67853         NaT
# 48891            Bushwick  40.70184         NaT
# 48892              Harlem  40.81475         NaT
# 48893      Hell's Kitchen  40.75751         NaT
# 48894      Hell's Kitchen  40.76404         NaT
#
# [48895 rows x 3 columns]

# %% [markdown]
# # Missing Values

# %%
bnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# availability_365_categories           0
# minimum_night_categories              0
# number_of_reviews_categories          0
# price_categories                      0
# dtype: int64

# %%
round((bnb_df.isnull().sum()/len(bnb_df))*100,2)
# Out:
# id                                 0.00
# name                               0.03
# host_id                            0.00
# host_name                          0.04
# neighbourhood_group                0.00
# neighbourhood                      0.00
# latitude                           0.00
# longitude                          0.00
# room_type                          0.00
# price                              0.00
# minimum_nights                     0.00
# number_of_reviews                  0.00
# last_review                       20.56
# reviews_per_month                 20.56
# calculated_host_listings_count     0.00
# availability_365                   0.00
# availability_365_categories        0.00
# minimum_night_categories           0.00
# number_of_reviews_categories       0.00
# price_categories                   0.00
# dtype: float64

# %% [markdown]
# #### Two columns (last_review , reviews_per_month) has around 20.56% missing values. name and host_name has 0.3% and 0.4 % missing values
# - We need to see if the values are, MCAR: It stands for Missing completely at random.
# The reason behind the missing value is not dependent on any other features or if it is MNAR: It stands for Missing not at random. There is a specific reason behind the missing value.
# #### There is no dropping or imputation of columns as we are just analyzing the dataset and not making a model.Also most of the features are important for our analysis.

# %%
bnb_df1 = bnb_df.loc[bnb_df.last_review.isnull(),:]
bnb_df1
# Out:
#              id                                               name   host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19         7750                  Huge 2 BR Upper East  Cental Park     17985
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36        11452                        Clean and Quiet in Brooklyn      7355
# 38        11943                          Country space in the city     45445
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
bnb_df1.groupby('neighbourhood_group').neighbourhood_group.count()
# Out:
# neighbourhood_group
# Bronx             215
# Brooklyn         3657
# Manhattan        5029
# Queens           1092
# Staten Island      59
# Name: neighbourhood_group, dtype: int64

# %%
bnb_df.groupby('neighbourhood_group').neighbourhood_group.count()
# Out:
# neighbourhood_group
# Bronx             1091
# Brooklyn         20104
# Manhattan        21661
# Queens            5666
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
(bnb_df1.groupby('neighbourhood_group').neighbourhood_group.count()/bnb_df.groupby('neighbourhood_group').neighbourhood_group.count())*100
# Out:
# neighbourhood_group
# Bronx            19.706691
# Brooklyn         18.190410
# Manhattan        23.216841
# Queens           19.272856
# Staten Island    15.817694
# Name: neighbourhood_group, dtype: float64

# %%
((bnb_df1.groupby('neighbourhood_group').neighbourhood_group.count()/bnb_df.groupby('neighbourhood_group').neighbourhood_group.count())*100).plot.bar()
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %%
((bnb_df1.groupby('neighbourhood_group').neighbourhood_group.count()/bnb_df.groupby('neighbourhood_group').neighbourhood_group.count())*100).mean()
# Out:
# 19.240898461107257

# %%
bnb_df1.head()
# Out:
#        id                                               name  host_id  \
# 2    3647                THE VILLAGE OF HARLEM....NEW YORK !     4632
# 19   7750                  Huge 2 BR Upper East  Cental Park    17985
# 26   8700  Magnifique Suite au N de Manhattan - vue Cloitres    26394
# 36  11452                        Clean and Quiet in Brooklyn     7355
# 38  11943                          Country space in the city    45445
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 2         Elisabeth           Manhattan              Harlem  40.80902
# 19             Sing           Manhattan         East Harlem  40.79685
# 26  Claude & Sophie           Manhattan              Inwood  40.86754
# 36               Vt            Brooklyn  Bedford-Stuyvesant  40.68876
# 38          Harriet            Brooklyn            Flatbush  40.63702
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
bnb_df2 = (bnb_df1.groupby('room_type').room_type.count()/bnb_df.groupby('room_type').room_type.count())*100
bnb_df2
# Out:
# room_type
# Entire home/apt    19.981109
# Private room       20.877004
# Shared room        27.068966
# Name: room_type, dtype: float64

# %%
plt.title('Missing values')
sns.barplot(x = bnb_df2.index, y = bnb_df2.values)
plt.show()

# %%
print('Mean and Median of prices with last_review feature missing')
print('Mean   = ', bnb_df[bnb_df['last_review'].isnull()].price.mean())
print('Median = ', bnb_df[bnb_df['last_review'].isnull()].price.median())

print('\nMean and Median of prices with last_review feature not missing')
print('Mean   = ', bnb_df[bnb_df['last_review'].notnull()].price.mean())
print('Median = ', bnb_df[bnb_df['last_review'].notnull()].price.median())
# Out:
# Mean and Median of prices with last_review feature missing
# Mean   =  192.9190210903303
# Median =  120.0
#
# Mean and Median of prices with last_review feature not missing
# Mean   =  142.317946605566
# Median =  101.0

# %%
plt.figure(figsize=(20,12))

plt.subplot(2,1,1)
sns.boxplot(data = bnb_df[bnb_df['last_review'].isnull()] , x = 'price',  width= .8)

plt.subplot(2,1,2)
sns.boxplot(data = bnb_df[bnb_df['last_review'].notnull()] , x = 'price',  width= .8)

plt.show()

# %% [markdown]
# ####
# - The pricing is higher when 'last_review' feature is missing .
# - reviews are less likely to be given for shared rooms¶
# - When the prices are high reviews are less likely to be given
# - The above analysis seems to show that the missing values here are not MCAR (missing completely at random)

# %% [markdown]
# # Univariate Analysis

# %%
bnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
bnb_df.name.value_counts()
# Out:
# Hillside Hotel                                        18
# Home away from home                                   17
# New york Multi-unit building                          16
# Brooklyn Apartment                                    12
# Loft Suite @ The Box House Hotel                      11
#                                                       ..
# Brownstone garden 2 bedroom duplex, Central Park       1
# Bright Cozy Private Room near Columbia Univ            1
# 1 bdrm/large studio in a great location                1
# Cozy Private Room #2 Two Beds Near JFK and J Train     1
# Trendy duplex in the very heart of Hell's Kitchen      1
# Name: name, Length: 47896, dtype: int64

# %%
bnb_df.host_id.value_counts()
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: host_id, Length: 37457, dtype: int64

# %%
bnb_df.host_name.value_counts()
# Out:
# Michael              417
# David                403
# Sonder (NYC)         327
# John                 294
# Alex                 279
#                     ...
# Rhonycs                1
# Brandy-Courtney        1
# Shanthony              1
# Aurore And Jamila      1
# Ilgar & Aysel          1
# Name: host_name, Length: 11452, dtype: int64

# %%
bnb_df.host_name.value_counts().index[:10]
# Out:
# Index(['Michael', 'David', 'Sonder (NYC)', 'John', 'Alex', 'Blueground',
#        'Sarah', 'Daniel', 'Jessica', 'Maria'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = bnb_df.host_name.value_counts().index[:10] , y = bnb_df.host_name.value_counts().values[:10])
plt.show()

# %%
bnb_df.neighbourhood_group.value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
bnb_df.neighbourhood_group.value_counts(normalize= True) * 100
# Out:
# Manhattan        44.301053
# Brooklyn         41.116679
# Queens           11.588097
# Bronx             2.231312
# Staten Island     0.762859
# Name: neighbourhood_group, dtype: float64

# %%
plt.figure(figsize=(8,8))
plt.pie(x = bnb_df.neighbourhood_group.value_counts(normalize= True) * 100,labels = bnb_df.neighbourhood_group.value_counts(normalize= True).index)
plt.legend()
plt.show()

# %% [markdown]
# #### What are the neighbourhoods they need to target?
# 81 % of the listing are Manhattan and Brooklyn.

# %%
bnb_df.neighbourhood.value_counts()
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: neighbourhood, Length: 221, dtype: int64

# %%
bnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
bnb_df.room_type.value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
bnb_df.room_type.value_counts(normalize=True)*100
# Out:
# Entire home/apt    51.966459
# Private room       45.661111
# Shared room         2.372431
# Name: room_type, dtype: float64

# %%
plt.figure(figsize=(8,8))
plt.pie(x = bnb_df.room_type.value_counts(normalize= True) * 100,labels = bnb_df.room_type.value_counts(normalize= True).index,counterclock=False)
plt.legend()
plt.show()

# %%
bnb_df.price.value_counts()
# Out:
# 100    2051
# 150    2047
# 50     1534
# 60     1458
# 200    1401
#        ...
# 780       1
# 386       1
# 888       1
# 483       1
# 338       1
# Name: price, Length: 674, dtype: int64

# %%
bnb_df.price.value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(data = bnb_df.price)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = bnb_df.price,kde = True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize=(10,7))
sns.set_theme(style="whitegrid")
#tips = sns.load_dataset("tips")
sns.boxplot(y = bnb_df.price,width=0.8,
    dodge=True,
    fliersize=6,
    linewidth=.5,
    whis=1.5,
    color=None)
plt.show()

# %%
bnb_df.minimum_nights.value_counts()
# Out:
# 1      12720
# 2      11696
# 3       7999
# 30      3760
# 4       3303
#        ...
# 186        1
# 366        1
# 68         1
# 87         1
# 36         1
# Name: minimum_nights, Length: 109, dtype: int64

# %%
bnb_df.minimum_nights.describe()
# Out:
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data = bnb_df.minimum_nights,fliersize=3)
plt.show()

# %%
plt.hist(data = bnb_df, x = 'minimum_nights',bins=80,range=(0,35),density=True)
plt.show()

# %%
plt.hist(data = bnb_df, x = 'minimum_nights',bins=80,range=(0,35))
plt.show()

# %%
bnb_df.number_of_reviews.describe()
# Out:
# count    48895.000000
# mean        23.274466
# std         44.550582
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         24.000000
# max        629.000000
# Name: number_of_reviews, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data = bnb_df.number_of_reviews,fliersize=3)
plt.show()

# %%
plt.hist(data = bnb_df, x = 'number_of_reviews',bins=80,range=(0,60))
plt.show()

# %%
plt.hist(data = bnb_df, x = 'number_of_reviews',bins=80,range=(0,60),density=True)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.histplot(data = bnb_df, x = 'number_of_reviews',bins=100,binrange=(0,300))
plt.show()

# %%
bnb_df.reviews_per_month.describe()
# Out:
# count    38843.000000
# mean         1.373221
# std          1.680442
# min          0.010000
# 25%          0.190000
# 50%          0.720000
# 75%          2.020000
# max         58.500000
# Name: reviews_per_month, dtype: float64

# %%
plt.figure(figsize = (20,6))
sns.boxplot(data = bnb_df , x = 'reviews_per_month')
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.histplot(data = bnb_df, x = 'reviews_per_month',bins=100,binrange=(0,30))
plt.show()

# %%
bnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
bnb_df.calculated_host_listings_count.describe()
# Out:
# count    48895.000000
# mean         7.143982
# std         32.952519
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        327.000000
# Name: calculated_host_listings_count, dtype: float64

# %%
plt.figure(figsize = (20,6))
sns.boxplot(data = bnb_df , x = 'calculated_host_listings_count')
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.histplot(data = bnb_df, x = 'calculated_host_listings_count',bins=40,binrange=(0,20))
plt.show()

# %%
bnb_df.availability_365.describe()
# Out:
# count    48895.000000
# mean       112.781327
# std        131.622289
# min          0.000000
# 25%          0.000000
# 50%         45.000000
# 75%        227.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %%
plt.figure(figsize = (12,4))
sns.boxplot(data = bnb_df , x = 'availability_365')
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.histplot(data = bnb_df, x = 'availability_365',bins=50,binrange=(0,365))
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.histplot(data = bnb_df, x = 'availability_365',bins=50,binrange=(5,365))
plt.show()

# %%
bnb_df.minimum_night_categories.value_counts(normalize= True)*100
# Out:
# Low          40.280192
# very Low     26.014930
# very High    14.997444
# Medium       12.960425
# High          5.747009
# Name: minimum_night_categories, dtype: float64

# %%
plt.figure(figsize=(12,7))
plt.title('Minimum night categories', fontdict={'fontsize': 20})
plt.pie(x = bnb_df.minimum_night_categories.value_counts(),labels=bnb_df.minimum_night_categories.value_counts().index)
plt.show()

# %%
bnb_df.number_of_reviews.describe()
# Out:
# count    48895.000000
# mean        23.274466
# std         44.550582
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         24.000000
# max        629.000000
# Name: number_of_reviews, dtype: float64

# %%
bnb_df.number_of_reviews_categories.value_counts()
# Out:
# Low          26032
# very Low     12720
# High          5893
# Medium        3503
# very High      747
# Name: number_of_reviews_categories, dtype: int64

# %%
bnb_df.number_of_reviews_categories.value_counts(normalize=True)*100
# Out:
# Low          53.240618
# very Low     26.014930
# High         12.052357
# Medium        7.164332
# very High     1.527764
# Name: number_of_reviews_categories, dtype: float64

# %%
plt.figure(figsize=(12,7))
plt.title('number_of_reviews_categories', fontdict={'fontsize': 20})
plt.pie(x = bnb_df.number_of_reviews_categories.value_counts(),labels=bnb_df.number_of_reviews_categories.value_counts().index)
plt.show()

# %%
bnb_df['price_categories'].value_counts()
# Out:
# Low          22998
# very Low     12720
# Medium        7556
# High          5447
# very High      174
# Name: price_categories, dtype: int64

# %%
bnb_df['price_categories'].value_counts(normalize=True)*100
# Out:
# Low          47.035484
# very Low     26.014930
# Medium       15.453523
# High         11.140198
# very High     0.355865
# Name: price_categories, dtype: float64

# %%
bnb_df['price_categories'].describe()
# Out:
# count     48895
# unique        5
# top         Low
# freq      22998
# Name: price_categories, dtype: object

# %%
plt.figure(figsize=(12,7))
plt.title('price_categories', fontdict={'fontsize': 20})
plt.pie(x = bnb_df.price_categories.value_counts(),labels=bnb_df.price_categories.value_counts().index,)
plt.show()

# %% [markdown]
# #### What is the pricing ranges preferred by customers?
# 'Low' price ranges are preferred by custumers followed by very 'Low' price ranges.

# %%
47.035484 + 26.014930
# Out:
# 73.05041399999999

# %% [markdown]
# # Bivariate and Multivariate Analysis

# %%
bnb_df[numerical_columns].head()
# Out:
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
# 2    150               3                  0                NaN
# 3     89               1                270               4.64
# 4     80              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
bnb_df[numerical_columns].corr()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000        0.042799          -0.047954
# minimum_nights                  0.042799        1.000000          -0.080116
# number_of_reviews              -0.047954       -0.080116           1.000000
# reviews_per_month              -0.030608       -0.121702           0.549868
# calculated_host_listings_count  0.057472        0.127960          -0.072376
# availability_365                0.081829        0.144303           0.172028
#
#                                 reviews_per_month  \
# price                                   -0.030608
# minimum_nights                          -0.121702
# number_of_reviews                        0.549868
# reviews_per_month                        1.000000
# calculated_host_listings_count          -0.009421
# availability_365                         0.185791
#
#                                 calculated_host_listings_count  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data = bnb_df[numerical_columns].corr())
plt.show()

# %%
corr_matrix = bnb_df[numerical_columns].corr().abs()


sol = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
                  .stack()
                  .sort_values(ascending=False))

# %%
corr_matrix
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000        0.042799           0.047954
# minimum_nights                  0.042799        1.000000           0.080116
# number_of_reviews               0.047954        0.080116           1.000000
# reviews_per_month               0.030608        0.121702           0.549868
# calculated_host_listings_count  0.057472        0.127960           0.072376
# availability_365                0.081829        0.144303           0.172028
#
#                                 reviews_per_month  \
# price                                    0.030608
# minimum_nights                           0.121702
# number_of_reviews                        0.549868
# reviews_per_month                        1.000000
# calculated_host_listings_count           0.009421
# availability_365                         0.185791
#
#                                 calculated_host_listings_count  \
# ...

# %%
sol
# Out:
# number_of_reviews               reviews_per_month                 0.549868
# calculated_host_listings_count  availability_365                  0.225701
# reviews_per_month               availability_365                  0.185791
# number_of_reviews               availability_365                  0.172028
# minimum_nights                  availability_365                  0.144303
#                                 calculated_host_listings_count    0.127960
#                                 reviews_per_month                 0.121702
# price                           availability_365                  0.081829
# minimum_nights                  number_of_reviews                 0.080116
# number_of_reviews               calculated_host_listings_count    0.072376
# price                           calculated_host_listings_count    0.057472
#                                 number_of_reviews                 0.047954
# ...

# %%
x1 = bnb_df.groupby('number_of_reviews_categories').price.sum().sort_values(ascending = False)
x1
# Out:
# number_of_reviews_categories
# Low          4002323
# very Low     1806531
# High          971346
# Medium        508647
# very High     178431
# Name: price, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x = x1.index,y = x1.values)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x = bnb_df.number_of_reviews_categories , y = bnb_df.price)
# Out:
# <Axes: xlabel='number_of_reviews_categories', ylabel='price'>

# %%
bnb_df.groupby('number_of_reviews_categories').price.mean().sort_values()
# Out:
# number_of_reviews_categories
# very Low     142.022877
# Medium       145.203254
# Low          153.746274
# High         164.830477
# very High    238.863454
# Name: price, dtype: float64

# %%
bnb_df.groupby('number_of_reviews_categories').price.median().sort_values()
# Out:
# number_of_reviews_categories
# very Low      90.0
# Medium       105.0
# High         120.0
# Low          120.0
# very High    120.0
# Name: price, dtype: float64

# %%
x2 = pd.DataFrame(x1)
x2 = x2.reset_index()
x2
# Out:
#   number_of_reviews_categories    price
# 0                          Low  4002323
# 1                     very Low  1806531
# 2                         High   971346
# 3                       Medium   508647
# 4                    very High   178431

# %%
((x2.groupby('number_of_reviews_categories').price.sum()/x2.price.sum())*100).sort_values(ascending = True)
# Out:
# number_of_reviews_categories
# very High     2.389505
# Medium        6.811679
# High         13.008033
# very Low     24.192631
# Low          53.598152
# Name: price, dtype: float64

# %% [markdown]
# #### What is the pricing ranges preferred by customers?
# The total price for 'Low' or 'very Low' number_of_reviews_categories are high.

# %% [markdown]
# #### Room Types and review catagories:

# %%
bnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
bnb_df.room_type.value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
pd.crosstab(bnb_df['room_type'], bnb_df['number_of_reviews_categories'])
# Out:
# number_of_reviews_categories  High    Low  Medium  very High  very Low
# room_type
# Entire home/apt               3809  14909    1960        504      4227
# Private room                  1950  10769    1494        226      7887
# Shared room                    134    354      49         17       606

# %%
bnb_df.groupby('room_type').number_of_reviews.sum()
# Out:
# room_type
# Entire home/apt    580403
# Private room       538346
# Shared room         19256
# Name: number_of_reviews, dtype: int64

# %%
bnb_df.groupby('room_type').number_of_reviews.sum()/bnb_df.room_type.value_counts()
# Out:
# room_type
# Entire home/apt    22.842418
# Private room       24.112962
# Shared room        16.600000
# dtype: float64

# %% [markdown]
# #### Room types and Price Catagories:

# %%
pd.crosstab(bnb_df['room_type'], bnb_df['price_categories'])
# Out:
# price_categories  High    Low  Medium  very High  very Low
# room_type
# Entire home/apt   3714  13086    4262        120      4227
# Private room      1620   9597    3170         52      7887
# Shared room        113    315     124          2       606

# %%
bnb_df.room_type.value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
bnb_df.groupby('room_type').reviews_per_month.mean()
# Out:
# room_type
# Entire home/apt    1.306578
# Private room       1.445209
# Shared room        1.471726
# Name: reviews_per_month, dtype: float64

# %%
bnb_df.groupby('room_type').reviews_per_month.median()
# Out:
# room_type
# Entire home/apt    0.66
# Private room       0.77
# Shared room        0.98
# Name: reviews_per_month, dtype: float64

# %%
bnb_df.groupby('room_type').reviews_per_month.sum()
# Out:
# room_type
# Entire home/apt    26565.34
# Private room       25529.62
# Shared room         1245.08
# Name: reviews_per_month, dtype: float64

# %%
plt.figure(figsize=(70,8))
sns.boxplot(data = bnb_df, y = 'room_type' ,x = 'reviews_per_month')
plt.xticks(np.arange(0,100,.5))
plt.show()

# %%
bnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
bnb_df.groupby('minimum_night_categories').reviews_per_month.sum().sort_values()
# Out:
# minimum_night_categories
# High          1227.57
# very High     2235.19
# Medium        4689.73
# very Low     20395.49
# Low          24792.06
# Name: reviews_per_month, dtype: float64

# %%
plt.figure(figsize=(70,8))
sns.boxplot(data = bnb_df, y = 'minimum_night_categories' ,x = 'reviews_per_month')
plt.xticks(np.arange(0,100,.5))
plt.show()

# %%
bnb_df.availability_365_categories.value_counts()
# Out:
# very Low     17941
# Low          11829
# very High     8108
# Medium        5792
# High          5225
# Name: availability_365_categories, dtype: int64

# %%
pd.DataFrame(bnb_df.groupby(['availability_365_categories','price_categories']).reviews_per_month.mean())
# Out:
#                                               reviews_per_month
# availability_365_categories price_categories
# High                        High                       0.598431
#                             Low                        2.200373
#                             Medium                     1.056111
#                             very High                  0.342308
#                             very Low                   3.289381
# Low                         High                       0.638307
#                             Low                        1.783956
#                             Medium                     0.883844
#                             very High                  0.803750
#                             very Low                   2.896114
# Medium                      High                       0.591070
#                             Low                        1.993565
#                             Medium                     1.157492
# ...

# %% [markdown]
# #### If the combination of availability and price is very high, reviews_per_month will be low on average Very high availability and very low price are likely to get more reviews.

# %%
bnb_df.to_csv('AB_NYC_2019_processed.csv')

# %% [markdown]
# # End of File
